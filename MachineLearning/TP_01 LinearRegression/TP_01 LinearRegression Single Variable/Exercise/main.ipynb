# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('canada_per_capita_income.csv')
df.head()
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
# %matplotlib inline
plt.xlabel("Year")
plt.ylabel("income (US$)")
plt.scatter(df.year, df.income, color='red', marker='+')
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']], df.income)
# Out:
# LinearRegression()

# %%
reg.predict([[1980]])
# Out:
# c:\Users\Raouf\anaconda3\envs\ML\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([8150.09108551])

# %%
# y = m * x + b
# x is the area want to predict
reg.coef_ # reg.coef_ show the m
# Out:
# array([828.46507522])

# %%
reg.intercept_ # reg.intercept_ show the b
# Out:
# -1632210.7578554575

# %%
reg.predict([[1980]])
# Out:
# c:\Users\Raouf\anaconda3\envs\ML\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([8150.09108551])

# %%
# y = m * x + b
y = 828.46507522 * 1980 - 1632210.7578554575
y
# Out:
# 8150.091080142651

# %%
df_test = pd.read_csv('year.csv')
df_test.head(3)
# Out:
#    year
# 0  1970
# 1  1980
# 2  1990

# %%
income_predict = reg.predict(df_test)
df_test['income_predict'] = income_predict
df_test
# Out:
#     year  income_predict
# 0   1970     -134.559667
# 1   1980     8150.091086
# 2   1990    16434.741838
# 3   1995    20577.067214
# 4   1996    21405.532289
# 5   2001    25547.857665
# 6   2003    27204.787816
# 7   2008    31347.113192
# 8   2012    34660.973493
# 9   2026    46259.484546
# 10  2050    66142.646351
# 11  2080    90996.598608
# 12  2090    99281.249360
# 13  2092   100938.179510

# %%
df_test.to_csv('predict.csv',index=0) # index=0  to remove the indexing in the file csv
df.head()
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
# %matplotlib inline
plt.xlabel("Year", fontsize=20)
plt.ylabel("income (US$)", fontsize=20)
plt.scatter(df.year, df.income, color='red', marker='+')
plt.plot(df.year, reg.predict(df[['year']]), color = 'blue')
plt.show()
